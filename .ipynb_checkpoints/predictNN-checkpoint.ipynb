# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing
# %matplotlib inline

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import pathlib

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

import util

import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.1.0

# %%
df = pd.read_csv('heart_failure_clinical_records_dataset.csv')

# %% [markdown]
# Train/Test Split

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.2)

# %%
train.head()
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 288  65.0        0                       892         1                 35
# 122  60.0        0                        96         1                 38
# 56   70.0        1                        75         0                 35
# 193  73.0        1                       231         1                 30
# 218  68.0        1                      1021         1                 35
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 288                    0  263358.03              1.10           142    0
# 122                    0  228000.00              0.75           140    0
# 56                     0  223000.00              2.70           138    1
# 193                    0  160000.00              1.18           142    1
# 218                    0  271000.00              1.10           134    1
#
#      smoking  time  DEATH_EVENT
# 288        0   256            0
# 122        0    95            0
# 56         1    54            0
# 193        1   180            0
# 218        0   197            0

# %% [markdown]
# # Create Model

# %%
import models

# set initial bias
neg, pos = np.bincount(df['DEATH_EVENT'])# set count negative and positive samples
initial_bias = np.log([pos/neg])


mobj = models.modelObj()
model = mobj.create_model(len(train.keys())-1, bias = initial_bias)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                208
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 225
# Trainable params: 225
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Normalize Data

# %%
train_y = train.pop('DEATH_EVENT')
train_x = util.norm(train)
train_x.head()

test_y = test.pop('DEATH_EVENT')
test_x = util.norm(test)

# %% [markdown]
# # Train Model

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_auc', 
    verbose=1,
    patience=10,
    mode='max',
    restore_best_weights=True)

# %%
train_x.head()
# Out:
#          0    1         2    3         4    5         6         7       8   \
# 0  0.454545  0.0  0.110075  1.0  0.307692  0.0  0.460046  0.056818  0.8125
# 1  0.363636  0.0  0.008428  1.0  0.353846  0.0  0.391774  0.017045  0.7500
# 2  0.545455  1.0  0.005746  0.0  0.307692  0.0  0.382120  0.238636  0.6875
# 3  0.600000  1.0  0.025667  1.0  0.230769  0.0  0.260475  0.065909  0.8125
# 4  0.509091  1.0  0.126548  1.0  0.307692  0.0  0.474802  0.056818  0.5625
#
#     9    10        11
# 0  0.0  0.0  0.896797
# 1  0.0  0.0  0.323843
# 2  1.0  1.0  0.177936
# 3  1.0  1.0  0.626335
# 4  1.0  0.0  0.686833

# %%
print(np.unique(train_y))

non_resampled_history = model.fit(
    train_x,
    train_y,
    batch_size=mobj.BATCH_SIZE,
    epochs=mobj.EPOCHS,
    callbacks = [early_stopping, models.printDot()],
    validation_split=0.2
    )
# Out:
# [0 1]
# Train on 191 samples, validate on 48 samples
# Epoch 1/100
#  32/191 [====>.........................] - ETA: 8s - loss: 0.8640 - tp: 7.0000 - fp: 16.0000 - tn: 8.0000 - fn: 1.0000 - accuracy: 0.4688 - precision: 0.3043 - recall: 0.8750 - auc: 0.5104.
# 191/191 [==============================] - 2s 12ms/sample - loss: 0.8278 - tp: 45.0000 - fp: 87.0000 - tn: 44.0000 - fn: 15.0000 - accuracy: 0.4660 - precision: 0.3409 - recall: 0.7500 - auc: 0.5464 - val_loss: 0.8078 - val_tp: 11.0000 - val_fp: 25.0000 - val_tn: 7.0000 - val_fn: 5.0000 - val_accuracy: 0.3750 - val_precision: 0.3056 - val_recall: 0.6875 - val_auc: 0.4424
# Epoch 2/100
# 191/191 [==============================] - 0s 308us/sample - loss: 0.8206 - tp: 36.0000 - fp: 85.0000 - tn: 46.0000 - fn: 24.0000 - accuracy: 0.4293 - precision: 0.2975 - recall: 0.6000 - auc: 0.5013 - val_loss: 0.7820 - val_tp: 9.0000 - val_fp: 22.0000 - val_tn: 10.0000 - val_fn: 7.0000 - val_accuracy: 0.3958 - val_precision: 0.2903 - val_recall: 0.5625 - val_auc: 0.4453
# Epoch 3/100
# 191/191 [==============================] - 0s 273us/sample - loss: 0.8099 - tp: 32.0000 - fp: 87.0000 - tn: 44.0000 - fn: 28.0000 - accuracy: 0.3979 - precision: 0.2689 - recall: 0.5333 - auc: 0.4371 - val_loss: 0.7594 - val_tp: 9.0000 - val_fp: 21.0000 - val_tn: 11.0000 - val_fn: 7.0000 - val_accuracy: 0.4167 - val_precision: 0.3000 - val_recall: 0.5625 - val_auc: 0.4473
# Epoch 4/100
# 191/191 [==============================] - 0s 287us/sample - loss: 0.7842 - tp: 33.0000 - fp: 79.0000 - tn: 52.0000 - fn: 27.0000 - accuracy: 0.4450 - precision: 0.2946 - recall: 0.5500 - auc: 0.4809 - val_loss: 0.7409 - val_tp: 9.0000 - val_fp: 21.0000 - val_tn: 11.0000 - val_fn: 7.0000 - val_accuracy: 0.4167 - val_precision: 0.3000 - val_recall: 0.5625 - val_auc: 0.4443
# Epoch 5/100
# 191/191 [==============================] - 0s 292us/sample - loss: 0.7900 - tp: 25.0000 - fp: 73.0000 - tn: 58.0000 - fn: 35.0000 - accuracy: 0.4346 - precision: 0.2551 - recall: 0.4167 - auc: 0.4335 - val_loss: 0.7264 - val_tp: 7.0000 - val_fp: 16.0000 - val_tn: 16.0000 - val_fn: 9.0000 - val_accuracy: 0.4792 - val_precision: 0.3043 - val_recall: 0.4375 - val_auc: 0.4463
# Epoch 6/100
# 191/191 [==============================] - 0s 292us/sample - loss: 0.7829 - tp: 27.0000 - fp: 70.0000 - tn: 61.0000 - fn: 33.0000 - accuracy: 0.4607 - precision: 0.2784 - recall: 0.4500 - auc: 0.4536 - val_loss: 0.7152 - val_tp: 6.0000 - val_fp: 9.0000 - val_tn: 23.0000 - val_fn: 10.0000 - val_accuracy: 0.6042 - val_precision: 0.4000 - val_recall: 0.3750 - val_auc: 0.4463
# Epoch 7/100
# 191/191 [==============================] - 0s 292us/sample - loss: 0.7243 - tp: 28.0000 - fp: 63.0000 - tn: 68.0000 - fn: 32.0000 - accuracy: 0.5026 - precision: 0.3077 - recall: 0.4667 - auc: 0.5035 - val_loss: 0.7057 - val_tp: 6.0000 - val_fp: 8.0000 - val_tn: 24.0000 - val_fn: 10.0000 - val_accuracy: 0.6250 - val_precision: 0.4286 - val_recall: 0.3750 - val_auc: 0.4678
# Epoch 8/100
# 191/191 [==============================] - 0s 272us/sample - loss: 0.7270 - tp: 29.0000 - fp: 61.0000 - tn: 70.0000 - fn: 31.0000 - accuracy: 0.5183 - precision: 0.3222 - recall: 0.4833 - auc: 0.4976 - val_loss: 0.6973 - val_tp: 5.0000 - val_fp: 8.0000 - val_tn: 24.0000 - val_fn: 11.0000 - val_accuracy: 0.6042 - val_precision: 0.3846 - val_recall: 0.3125 - val_auc: 0.4707
# Epoch 9/100
# 191/191 [==============================] - 0s 277us/sample - loss: 0.7550 - tp: 14.0000 - fp: 60.0000 - tn: 71.0000 - fn: 46.0000 - accuracy: 0.4450 - precision: 0.1892 - recall: 0.2333 - auc: 0.3992 - val_loss: 0.6900 - val_tp: 3.0000 - val_fp: 7.0000 - val_tn: 25.0000 - val_fn: 13.0000 - val_accuracy: 0.5833 - val_precision: 0.3000 - val_recall: 0.1875 - val_auc: 0.4795
# Epoch 10/100
# 191/191 [==============================] - 0s 287us/sample - loss: 0.7029 - tp: 19.0000 - fp: 46.0000 - tn: 85.0000 - fn: 41.0000 - accuracy: 0.5445 - precision: 0.2923 - recall: 0.3167 - auc: 0.4585 - val_loss: 0.6838 - val_tp: 2.0000 - val_fp: 7.0000 - val_tn: 25.0000 - val_fn: 14.0000 - val_accuracy: 0.5625 - val_precision: 0.2222 - val_recall: 0.1250 - val_auc: 0.4795
# Epoch 11/100
#  32/191 [====>.........................] - ETA: 0s - loss: 0.6470 - tp: 4.0000 - fp: 9.0000 - tn: 14.0000 - fn: 5.0000 - accuracy: 0.5625 - precision: 0.3077 - recall: 0.4444 - auc: 0.5531.
# 191/191 [==============================] - 0s 292us/sample - loss: 0.6774 - tp: 27.0000 - fp: 48.0000 - tn: 83.0000 - fn: 33.0000 - accuracy: 0.5759 - precision: 0.3600 - recall: 0.4500 - auc: 0.5338 - val_loss: 0.6787 - val_tp: 2.0000 - val_fp: 6.0000 - val_tn: 26.0000 - val_fn: 14.0000 - val_accuracy: 0.5833 - val_precision: 0.2500 - val_recall: 0.1250 - val_auc: 0.4805
# Epoch 12/100
# 191/191 [==============================] - 0s 324us/sample - loss: 0.7223 - tp: 20.0000 - fp: 44.0000 - tn: 87.0000 - fn: 40.0000 - accuracy: 0.5602 - precision: 0.3125 - recall: 0.3333 - auc: 0.4567 - val_loss: 0.6744 - val_tp: 2.0000 - val_fp: 4.0000 - val_tn: 28.0000 - val_fn: 14.0000 - val_accuracy: 0.6250 - val_precision: 0.3333 - val_recall: 0.1250 - val_auc: 0.4834
# Epoch 13/100
# 191/191 [==============================] - 0s 298us/sample - loss: 0.7230 - tp: 17.0000 - fp: 49.0000 - tn: 82.0000 - fn: 43.0000 - accuracy: 0.5183 - precision: 0.2576 - recall: 0.2833 - auc: 0.4196 - val_loss: 0.6704 - val_tp: 2.0000 - val_fp: 4.0000 - val_tn: 28.0000 - val_fn: 14.0000 - val_accuracy: 0.6250 - val_precision: 0.3333 - val_recall: 0.1250 - val_auc: 0.4873
# Epoch 14/100
# 191/191 [==============================] - 0s 282us/sample - loss: 0.6841 - tp: 18.0000 - fp: 35.0000 - tn: 96.0000 - fn: 42.0000 - accuracy: 0.5969 - precision: 0.3396 - recall: 0.3000 - auc: 0.4746 - val_loss: 0.6669 - val_tp: 1.0000 - val_fp: 3.0000 - val_tn: 29.0000 - val_fn: 15.0000 - val_accuracy: 0.6250 - val_precision: 0.2500 - val_recall: 0.0625 - val_auc: 0.4932
# Epoch 15/100
# 191/191 [==============================] - 0s 298us/sample - loss: 0.6648 - tp: 20.0000 - fp: 40.0000 - tn: 91.0000 - fn: 40.0000 - accuracy: 0.5812 - precision: 0.3333 - recall: 0.3333 - auc: 0.5264 - val_loss: 0.6635 - val_tp: 1.0000 - val_fp: 3.0000 - val_tn: 29.0000 - val_fn: 15.0000 - val_accuracy: 0.6250 - val_precision: 0.2500 - val_recall: 0.0625 - val_auc: 0.4912
# Epoch 16/100
# 191/191 [==============================] - 0s 308us/sample - loss: 0.6716 - tp: 15.0000 - fp: 26.0000 - tn: 105.0000 - fn: 45.0000 - accuracy: 0.6283 - precision: 0.3659 - recall: 0.2500 - auc: 0.5055 - val_loss: 0.6597 - val_tp: 1.0000 - val_fp: 3.0000 - val_tn: 29.0000 - val_fn: 15.0000 - val_accuracy: 0.6250 - val_precision: 0.2500 - val_recall: 0.0625 - val_auc: 0.4990
# Epoch 17/100
# 191/191 [==============================] - 0s 292us/sample - loss: 0.6628 - tp: 16.0000 - fp: 24.0000 - tn: 107.0000 - fn: 44.0000 - accuracy: 0.6440 - precision: 0.4000 - recall: 0.2667 - auc: 0.5152 - val_loss: 0.6570 - val_tp: 1.0000 - val_fp: 2.0000 - val_tn: 30.0000 - val_fn: 15.0000 - val_accuracy: 0.6458 - val_precision: 0.3333 - val_recall: 0.0625 - val_auc: 0.4961
# Epoch 18/100
# 191/191 [==============================] - 0s 298us/sample - loss: 0.6743 - tp: 15.0000 - fp: 27.0000 - tn: 104.0000 - fn: 45.0000 - accuracy: 0.6230 - precision: 0.3571 - recall: 0.2500 - auc: 0.5029 - val_loss: 0.6541 - val_tp: 0.0000e+00 - val_fp: 2.0000 - val_tn: 30.0000 - val_fn: 16.0000 - val_accuracy: 0.6250 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5010
# Epoch 19/100
# 191/191 [==============================] - 0s 287us/sample - loss: 0.6596 - tp: 21.0000 - fp: 36.0000 - tn: 95.0000 - fn: 39.0000 - accuracy: 0.6073 - precision: 0.3684 - recall: 0.3500 - auc: 0.5479 - val_loss: 0.6513 - val_tp: 0.0000e+00 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 16.0000 - val_accuracy: 0.6458 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5029
# Epoch 20/100
# 191/191 [==============================] - 0s 292us/sample - loss: 0.6344 - tp: 18.0000 - fp: 29.0000 - tn: 102.0000 - fn: 42.0000 - accuracy: 0.6283 - precision: 0.3830 - recall: 0.3000 - auc: 0.5761 - val_loss: 0.6484 - val_tp: 0.0000e+00 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 16.0000 - val_accuracy: 0.6458 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5137
# Epoch 21/100
#  32/191 [====>.........................] - ETA: 0s - loss: 0.5881 - tp: 1.0000 - fp: 5.0000 - tn: 20.0000 - fn: 6.0000 - accuracy: 0.6562 - precision: 0.1667 - recall: 0.1429 - auc: 0.5400.
# 191/191 [==============================] - 0s 287us/sample - loss: 0.6405 - tp: 15.0000 - fp: 23.0000 - tn: 108.0000 - fn: 45.0000 - accuracy: 0.6440 - precision: 0.3947 - recall: 0.2500 - auc: 0.5611 - val_loss: 0.6460 - val_tp: 0.0000e+00 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 16.0000 - val_accuracy: 0.6458 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5137
# Epoch 22/100
# 191/191 [==============================] - 0s 282us/sample - loss: 0.6555 - tp: 15.0000 - fp: 27.0000 - tn: 104.0000 - fn: 45.0000 - accuracy: 0.6230 - precision: 0.3571 - recall: 0.2500 - auc: 0.5179 - val_loss: 0.6436 - val_tp: 0.0000e+00 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 16.0000 - val_accuracy: 0.6458 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5205
# Epoch 23/100
# 191/191 [==============================] - 0s 308us/sample - loss: 0.6496 - tp: 13.0000 - fp: 30.0000 - tn: 101.0000 - fn: 47.0000 - accuracy: 0.5969 - precision: 0.3023 - recall: 0.2167 - auc: 0.5466 - val_loss: 0.6413 - val_tp: 0.0000e+00 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 16.0000 - val_accuracy: 0.6458 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5283
# Epoch 24/100
# 191/191 [==============================] - 0s 292us/sample - loss: 0.6571 - tp: 13.0000 - fp: 24.0000 - tn: 107.0000 - fn: 47.0000 - accuracy: 0.6283 - precision: 0.3514 - recall: 0.2167 - auc: 0.5115 - val_loss: 0.6390 - val_tp: 0.0000e+00 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 16.0000 - val_accuracy: 0.6458 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5400
# Epoch 25/100
# 191/191 [==============================] - 0s 256us/sample - loss: 0.6419 - tp: 13.0000 - fp: 17.0000 - tn: 114.0000 - fn: 47.0000 - accuracy: 0.6649 - precision: 0.4333 - recall: 0.2167 - auc: 0.5471 - val_loss: 0.6366 - val_tp: 0.0000e+00 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 16.0000 - val_accuracy: 0.6458 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5469
# Epoch 26/100
# 191/191 [==============================] - 0s 272us/sample - loss: 0.6570 - tp: 13.0000 - fp: 12.0000 - tn: 119.0000 - fn: 47.0000 - accuracy: 0.6911 - precision: 0.5200 - recall: 0.2167 - auc: 0.5098 - val_loss: 0.6343 - val_tp: 0.0000e+00 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 16.0000 - val_accuracy: 0.6458 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5605
# Epoch 27/100
# 191/191 [==============================] - 0s 272us/sample - loss: 0.6428 - tp: 14.0000 - fp: 14.0000 - tn: 117.0000 - fn: 46.0000 - accuracy: 0.6859 - precision: 0.5000 - recall: 0.2333 - auc: 0.5228 - val_loss: 0.6326 - val_tp: 0.0000e+00 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 16.0000 - val_accuracy: 0.6458 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5605
# Epoch 28/100
# 191/191 [==============================] - 0s 280us/sample - loss: 0.6385 - tp: 13.0000 - fp: 20.0000 - tn: 111.0000 - fn: 47.0000 - accuracy: 0.6492 - precision: 0.3939 - recall: 0.2167 - auc: 0.5424 - val_loss: 0.6305 - val_tp: 0.0000e+00 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 16.0000 - val_accuracy: 0.6458 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5869
# Epoch 29/100
# 191/191 [==============================] - 0s 277us/sample - loss: 0.6255 - tp: 16.0000 - fp: 14.0000 - tn: 117.0000 - fn: 44.0000 - accuracy: 0.6963 - precision: 0.5333 - recall: 0.2667 - auc: 0.5929 - val_loss: 0.6283 - val_tp: 0.0000e+00 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 16.0000 - val_accuracy: 0.6458 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5840
# Epoch 30/100
# 191/191 [==============================] - 0s 272us/sample - loss: 0.6382 - tp: 13.0000 - fp: 21.0000 - tn: 110.0000 - fn: 47.0000 - accuracy: 0.6440 - precision: 0.3824 - recall: 0.2167 - auc: 0.5401 - val_loss: 0.6261 - val_tp: 0.0000e+00 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 16.0000 - val_accuracy: 0.6458 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5977
# Epoch 31/100
#  32/191 [====>.........................] - ETA: 0s - loss: 0.5897 - tp: 2.0000 - fp: 3.0000 - tn: 21.0000 - fn: 6.0000 - accuracy: 0.7188 - precision: 0.4000 - recall: 0.2500 - auc: 0.5234.
# 191/191 [==============================] - 0s 261us/sample - loss: 0.5989 - tp: 15.0000 - fp: 18.0000 - tn: 113.0000 - fn: 45.0000 - accuracy: 0.6702 - precision: 0.4545 - recall: 0.2500 - auc: 0.6421 - val_loss: 0.6238 - val_tp: 0.0000e+00 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 16.0000 - val_accuracy: 0.6458 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6113
# Epoch 32/100
# 191/191 [==============================] - 0s 277us/sample - loss: 0.6255 - tp: 13.0000 - fp: 16.0000 - tn: 115.0000 - fn: 47.0000 - accuracy: 0.6702 - precision: 0.4483 - recall: 0.2167 - auc: 0.5827 - val_loss: 0.6217 - val_tp: 0.0000e+00 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 16.0000 - val_accuracy: 0.6458 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6211
# Epoch 33/100
# 191/191 [==============================] - 0s 282us/sample - loss: 0.6530 - tp: 9.0000 - fp: 15.0000 - tn: 116.0000 - fn: 51.0000 - accuracy: 0.6545 - precision: 0.3750 - recall: 0.1500 - auc: 0.5105 - val_loss: 0.6189 - val_tp: 0.0000e+00 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 16.0000 - val_accuracy: 0.6458 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6318
# Epoch 34/100
# 191/191 [==============================] - 0s 261us/sample - loss: 0.6161 - tp: 10.0000 - fp: 10.0000 - tn: 121.0000 - fn: 50.0000 - accuracy: 0.6859 - precision: 0.5000 - recall: 0.1667 - auc: 0.5940 - val_loss: 0.6165 - val_tp: 0.0000e+00 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 16.0000 - val_accuracy: 0.6458 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6426
# Epoch 35/100
# 191/191 [==============================] - 0s 287us/sample - loss: 0.6427 - tp: 7.0000 - fp: 13.0000 - tn: 118.0000 - fn: 53.0000 - accuracy: 0.6545 - precision: 0.3500 - recall: 0.1167 - auc: 0.5424 - val_loss: 0.6145 - val_tp: 0.0000e+00 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 16.0000 - val_accuracy: 0.6458 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6523
# Epoch 36/100
# 191/191 [==============================] - 0s 272us/sample - loss: 0.6290 - tp: 10.0000 - fp: 15.0000 - tn: 116.0000 - fn: 50.0000 - accuracy: 0.6597 - precision: 0.4000 - recall: 0.1667 - auc: 0.5553 - val_loss: 0.6132 - val_tp: 0.0000e+00 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 16.0000 - val_accuracy: 0.6458 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6553
# Epoch 37/100
# 191/191 [==============================] - 0s 282us/sample - loss: 0.6399 - tp: 10.0000 - fp: 9.0000 - tn: 122.0000 - fn: 50.0000 - accuracy: 0.6911 - precision: 0.5263 - recall: 0.1667 - auc: 0.5319 - val_loss: 0.6120 - val_tp: 0.0000e+00 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 16.0000 - val_accuracy: 0.6458 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6670
# Epoch 38/100
# 191/191 [==============================] - 0s 278us/sample - loss: 0.6268 - tp: 8.0000 - fp: 13.0000 - tn: 118.0000 - fn: 52.0000 - accuracy: 0.6597 - precision: 0.3810 - recall: 0.1333 - auc: 0.5723 - val_loss: 0.6101 - val_tp: 0.0000e+00 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 16.0000 - val_accuracy: 0.6458 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6895
# Epoch 39/100
# 191/191 [==============================] - 0s 266us/sample - loss: 0.6233 - tp: 9.0000 - fp: 14.0000 - tn: 117.0000 - fn: 51.0000 - accuracy: 0.6597 - precision: 0.3913 - recall: 0.1500 - auc: 0.5880 - val_loss: 0.6085 - val_tp: 0.0000e+00 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 16.0000 - val_accuracy: 0.6458 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7002
# Epoch 40/100
# 191/191 [==============================] - 0s 282us/sample - loss: 0.6120 - tp: 12.0000 - fp: 12.0000 - tn: 119.0000 - fn: 48.0000 - accuracy: 0.6859 - precision: 0.5000 - recall: 0.2000 - auc: 0.6156 - val_loss: 0.6068 - val_tp: 1.0000 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 15.0000 - val_accuracy: 0.6667 - val_precision: 0.5000 - val_recall: 0.0625 - val_auc: 0.7070
# Epoch 41/100
#  32/191 [====>.........................] - ETA: 0s - loss: 0.6241 - tp: 2.0000 - fp: 2.0000 - tn: 19.0000 - fn: 9.0000 - accuracy: 0.6562 - precision: 0.5000 - recall: 0.1818 - auc: 0.6364.
# 191/191 [==============================] - 0s 287us/sample - loss: 0.6179 - tp: 14.0000 - fp: 12.0000 - tn: 119.0000 - fn: 46.0000 - accuracy: 0.6963 - precision: 0.5385 - recall: 0.2333 - auc: 0.5933 - val_loss: 0.6043 - val_tp: 1.0000 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 15.0000 - val_accuracy: 0.6667 - val_precision: 0.5000 - val_recall: 0.0625 - val_auc: 0.7168
# Epoch 42/100
# 191/191 [==============================] - 0s 266us/sample - loss: 0.6092 - tp: 10.0000 - fp: 13.0000 - tn: 118.0000 - fn: 50.0000 - accuracy: 0.6702 - precision: 0.4348 - recall: 0.1667 - auc: 0.6062 - val_loss: 0.6019 - val_tp: 1.0000 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 15.0000 - val_accuracy: 0.6667 - val_precision: 0.5000 - val_recall: 0.0625 - val_auc: 0.7295
# Epoch 43/100
# 191/191 [==============================] - 0s 287us/sample - loss: 0.6136 - tp: 17.0000 - fp: 13.0000 - tn: 118.0000 - fn: 43.0000 - accuracy: 0.7068 - precision: 0.5667 - recall: 0.2833 - auc: 0.6056 - val_loss: 0.5995 - val_tp: 1.0000 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 15.0000 - val_accuracy: 0.6667 - val_precision: 0.5000 - val_recall: 0.0625 - val_auc: 0.7324
# Epoch 44/100
# 191/191 [==============================] - 0s 279us/sample - loss: 0.5862 - tp: 10.0000 - fp: 9.0000 - tn: 122.0000 - fn: 50.0000 - accuracy: 0.6911 - precision: 0.5263 - recall: 0.1667 - auc: 0.6523 - val_loss: 0.5976 - val_tp: 1.0000 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 15.0000 - val_accuracy: 0.6667 - val_precision: 0.5000 - val_recall: 0.0625 - val_auc: 0.7422
# Epoch 45/100
# 191/191 [==============================] - 0s 271us/sample - loss: 0.6229 - tp: 8.0000 - fp: 5.0000 - tn: 126.0000 - fn: 52.0000 - accuracy: 0.7016 - precision: 0.6154 - recall: 0.1333 - auc: 0.5482 - val_loss: 0.5956 - val_tp: 1.0000 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 15.0000 - val_accuracy: 0.6667 - val_precision: 0.5000 - val_recall: 0.0625 - val_auc: 0.7520
# Epoch 46/100
# 191/191 [==============================] - 0s 331us/sample - loss: 0.6099 - tp: 15.0000 - fp: 12.0000 - tn: 119.0000 - fn: 45.0000 - accuracy: 0.7016 - precision: 0.5556 - recall: 0.2500 - auc: 0.6028 - val_loss: 0.5937 - val_tp: 1.0000 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 15.0000 - val_accuracy: 0.6667 - val_precision: 0.5000 - val_recall: 0.0625 - val_auc: 0.7598
# Epoch 47/100
# 191/191 [==============================] - 0s 277us/sample - loss: 0.6074 - tp: 11.0000 - fp: 8.0000 - tn: 123.0000 - fn: 49.0000 - accuracy: 0.7016 - precision: 0.5789 - recall: 0.1833 - auc: 0.6108 - val_loss: 0.5915 - val_tp: 1.0000 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 15.0000 - val_accuracy: 0.6667 - val_precision: 0.5000 - val_recall: 0.0625 - val_auc: 0.7627
# Epoch 48/100
# 191/191 [==============================] - 0s 277us/sample - loss: 0.6160 - tp: 9.0000 - fp: 6.0000 - tn: 125.0000 - fn: 51.0000 - accuracy: 0.7016 - precision: 0.6000 - recall: 0.1500 - auc: 0.5861 - val_loss: 0.5896 - val_tp: 1.0000 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 15.0000 - val_accuracy: 0.6667 - val_precision: 0.5000 - val_recall: 0.0625 - val_auc: 0.7715
# Epoch 49/100
# 191/191 [==============================] - 0s 313us/sample - loss: 0.5755 - tp: 17.0000 - fp: 8.0000 - tn: 123.0000 - fn: 43.0000 - accuracy: 0.7330 - precision: 0.6800 - recall: 0.2833 - auc: 0.6816 - val_loss: 0.5874 - val_tp: 1.0000 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 15.0000 - val_accuracy: 0.6667 - val_precision: 0.5000 - val_recall: 0.0625 - val_auc: 0.7705
# Epoch 50/100
# 191/191 [==============================] - 0s 318us/sample - loss: 0.6154 - tp: 14.0000 - fp: 16.0000 - tn: 115.0000 - fn: 46.0000 - accuracy: 0.6754 - precision: 0.4667 - recall: 0.2333 - auc: 0.6001 - val_loss: 0.5852 - val_tp: 1.0000 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 15.0000 - val_accuracy: 0.6667 - val_precision: 0.5000 - val_recall: 0.0625 - val_auc: 0.7910
# Epoch 51/100
#  32/191 [====>.........................] - ETA: 0s - loss: 0.6046 - tp: 1.0000 - fp: 0.0000e+00 - tn: 23.0000 - fn: 8.0000 - accuracy: 0.7500 - precision: 1.0000 - recall: 0.1111 - auc: 0.5000.
# 191/191 [==============================] - 0s 303us/sample - loss: 0.6290 - tp: 9.0000 - fp: 8.0000 - tn: 123.0000 - fn: 51.0000 - accuracy: 0.6911 - precision: 0.5294 - recall: 0.1500 - auc: 0.5511 - val_loss: 0.5835 - val_tp: 1.0000 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 15.0000 - val_accuracy: 0.6667 - val_precision: 0.5000 - val_recall: 0.0625 - val_auc: 0.7939
# Epoch 52/100
# 191/191 [==============================] - 0s 319us/sample - loss: 0.5650 - tp: 15.0000 - fp: 8.0000 - tn: 123.0000 - fn: 45.0000 - accuracy: 0.7225 - precision: 0.6522 - recall: 0.2500 - auc: 0.7027 - val_loss: 0.5817 - val_tp: 1.0000 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 15.0000 - val_accuracy: 0.6667 - val_precision: 0.5000 - val_recall: 0.0625 - val_auc: 0.7998
# Epoch 53/100
# 191/191 [==============================] - 0s 308us/sample - loss: 0.5663 - tp: 14.0000 - fp: 9.0000 - tn: 122.0000 - fn: 46.0000 - accuracy: 0.7120 - precision: 0.6087 - recall: 0.2333 - auc: 0.7026 - val_loss: 0.5797 - val_tp: 1.0000 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 15.0000 - val_accuracy: 0.6667 - val_precision: 0.5000 - val_recall: 0.0625 - val_auc: 0.8037
# Epoch 54/100
# 191/191 [==============================] - 0s 329us/sample - loss: 0.5923 - tp: 11.0000 - fp: 11.0000 - tn: 120.0000 - fn: 49.0000 - accuracy: 0.6859 - precision: 0.5000 - recall: 0.1833 - auc: 0.6513 - val_loss: 0.5779 - val_tp: 1.0000 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 15.0000 - val_accuracy: 0.6667 - val_precision: 0.5000 - val_recall: 0.0625 - val_auc: 0.8086
# Epoch 55/100
# 191/191 [==============================] - 0s 292us/sample - loss: 0.5826 - tp: 10.0000 - fp: 6.0000 - tn: 125.0000 - fn: 50.0000 - accuracy: 0.7068 - precision: 0.6250 - recall: 0.1667 - auc: 0.6564 - val_loss: 0.5758 - val_tp: 1.0000 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 15.0000 - val_accuracy: 0.6667 - val_precision: 0.5000 - val_recall: 0.0625 - val_auc: 0.8105
# Epoch 56/100
# 191/191 [==============================] - 0s 313us/sample - loss: 0.5813 - tp: 11.0000 - fp: 7.0000 - tn: 124.0000 - fn: 49.0000 - accuracy: 0.7068 - precision: 0.6111 - recall: 0.1833 - auc: 0.6652 - val_loss: 0.5741 - val_tp: 1.0000 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 15.0000 - val_accuracy: 0.6667 - val_precision: 0.5000 - val_recall: 0.0625 - val_auc: 0.8135
# Epoch 57/100
# 191/191 [==============================] - 0s 324us/sample - loss: 0.5666 - tp: 17.0000 - fp: 10.0000 - tn: 121.0000 - fn: 43.0000 - accuracy: 0.7225 - precision: 0.6296 - recall: 0.2833 - auc: 0.6967 - val_loss: 0.5728 - val_tp: 2.0000 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 14.0000 - val_accuracy: 0.6875 - val_precision: 0.6667 - val_recall: 0.1250 - val_auc: 0.8135
# Epoch 58/100
# 191/191 [==============================] - 0s 329us/sample - loss: 0.5536 - tp: 16.0000 - fp: 12.0000 - tn: 119.0000 - fn: 44.0000 - accuracy: 0.7068 - precision: 0.5714 - recall: 0.2667 - auc: 0.7222 - val_loss: 0.5708 - val_tp: 2.0000 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 14.0000 - val_accuracy: 0.6875 - val_precision: 0.6667 - val_recall: 0.1250 - val_auc: 0.8105
# Epoch 59/100
# 191/191 [==============================] - 0s 308us/sample - loss: 0.5861 - tp: 14.0000 - fp: 8.0000 - tn: 123.0000 - fn: 46.0000 - accuracy: 0.7173 - precision: 0.6364 - recall: 0.2333 - auc: 0.6601 - val_loss: 0.5690 - val_tp: 2.0000 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 14.0000 - val_accuracy: 0.6875 - val_precision: 0.6667 - val_recall: 0.1250 - val_auc: 0.8125
# Epoch 60/100
# 191/191 [==============================] - 0s 319us/sample - loss: 0.5689 - tp: 17.0000 - fp: 9.0000 - tn: 122.0000 - fn: 43.0000 - accuracy: 0.7277 - precision: 0.6538 - recall: 0.2833 - auc: 0.6897 - val_loss: 0.5672 - val_tp: 2.0000 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 14.0000 - val_accuracy: 0.6875 - val_precision: 0.6667 - val_recall: 0.1250 - val_auc: 0.8174
# Epoch 61/100
#  32/191 [====>.........................] - ETA: 0s - loss: 0.4353 - tp: 4.0000 - fp: 0.0000e+00 - tn: 25.0000 - fn: 3.0000 - accuracy: 0.9062 - precision: 1.0000 - recall: 0.5714 - auc: 0.8886.
# 191/191 [==============================] - 0s 298us/sample - loss: 0.5584 - tp: 16.0000 - fp: 10.0000 - tn: 121.0000 - fn: 44.0000 - accuracy: 0.7173 - precision: 0.6154 - recall: 0.2667 - auc: 0.7233 - val_loss: 0.5656 - val_tp: 2.0000 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 14.0000 - val_accuracy: 0.6875 - val_precision: 0.6667 - val_recall: 0.1250 - val_auc: 0.8164
# Epoch 62/100
# 191/191 [==============================] - 0s 313us/sample - loss: 0.5786 - tp: 11.0000 - fp: 7.0000 - tn: 124.0000 - fn: 49.0000 - accuracy: 0.7068 - precision: 0.6111 - recall: 0.1833 - auc: 0.6711 - val_loss: 0.5645 - val_tp: 2.0000 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 14.0000 - val_accuracy: 0.6875 - val_precision: 0.6667 - val_recall: 0.1250 - val_auc: 0.8184
# Epoch 63/100
# 191/191 [==============================] - 0s 303us/sample - loss: 0.5632 - tp: 16.0000 - fp: 10.0000 - tn: 121.0000 - fn: 44.0000 - accuracy: 0.7173 - precision: 0.6154 - recall: 0.2667 - auc: 0.7045 - val_loss: 0.5630 - val_tp: 2.0000 - val_fp: 1.0000 - val_tn: 31.0000 - val_fn: 14.0000 - val_accuracy: 0.6875 - val_precision: 0.6667 - val_recall: 0.1250 - val_auc: 0.8203
# Epoch 64/100
# 191/191 [==============================] - 0s 303us/sample - loss: 0.5760 - tp: 14.0000 - fp: 7.0000 - tn: 124.0000 - fn: 46.0000 - accuracy: 0.7225 - precision: 0.6667 - recall: 0.2333 - auc: 0.6702 - val_loss: 0.5614 - val_tp: 2.0000 - val_fp: 0.0000e+00 - val_tn: 32.0000 - val_fn: 14.0000 - val_accuracy: 0.7083 - val_precision: 1.0000 - val_recall: 0.1250 - val_auc: 0.8232
# Epoch 65/100
# 191/191 [==============================] - 0s 282us/sample - loss: 0.5648 - tp: 16.0000 - fp: 8.0000 - tn: 123.0000 - fn: 44.0000 - accuracy: 0.7277 - precision: 0.6667 - recall: 0.2667 - auc: 0.6987 - val_loss: 0.5600 - val_tp: 2.0000 - val_fp: 0.0000e+00 - val_tn: 32.0000 - val_fn: 14.0000 - val_accuracy: 0.7083 - val_precision: 1.0000 - val_recall: 0.1250 - val_auc: 0.8252
# Epoch 66/100
# 191/191 [==============================] - 0s 292us/sample - loss: 0.5745 - tp: 13.0000 - fp: 11.0000 - tn: 120.0000 - fn: 47.0000 - accuracy: 0.6963 - precision: 0.5417 - recall: 0.2167 - auc: 0.6820 - val_loss: 0.5586 - val_tp: 2.0000 - val_fp: 0.0000e+00 - val_tn: 32.0000 - val_fn: 14.0000 - val_accuracy: 0.7083 - val_precision: 1.0000 - val_recall: 0.1250 - val_auc: 0.8252
# Epoch 67/100
# 191/191 [==============================] - 0s 287us/sample - loss: 0.5465 - tp: 18.0000 - fp: 9.0000 - tn: 122.0000 - fn: 42.0000 - accuracy: 0.7330 - precision: 0.6667 - recall: 0.3000 - auc: 0.7272 - val_loss: 0.5572 - val_tp: 2.0000 - val_fp: 0.0000e+00 - val_tn: 32.0000 - val_fn: 14.0000 - val_accuracy: 0.7083 - val_precision: 1.0000 - val_recall: 0.1250 - val_auc: 0.8271
# Epoch 68/100
# 191/191 [==============================] - 0s 298us/sample - loss: 0.5428 - tp: 15.0000 - fp: 8.0000 - tn: 123.0000 - fn: 45.0000 - accuracy: 0.7225 - precision: 0.6522 - recall: 0.2500 - auc: 0.7476 - val_loss: 0.5558 - val_tp: 2.0000 - val_fp: 0.0000e+00 - val_tn: 32.0000 - val_fn: 14.0000 - val_accuracy: 0.7083 - val_precision: 1.0000 - val_recall: 0.1250 - val_auc: 0.8262
# Epoch 69/100
# 191/191 [==============================] - 0s 298us/sample - loss: 0.5544 - tp: 14.0000 - fp: 7.0000 - tn: 124.0000 - fn: 46.0000 - accuracy: 0.7225 - precision: 0.6667 - recall: 0.2333 - auc: 0.7157 - val_loss: 0.5548 - val_tp: 3.0000 - val_fp: 0.0000e+00 - val_tn: 32.0000 - val_fn: 13.0000 - val_accuracy: 0.7292 - val_precision: 1.0000 - val_recall: 0.1875 - val_auc: 0.8232
# Epoch 70/100
# 191/191 [==============================] - 0s 308us/sample - loss: 0.5503 - tp: 17.0000 - fp: 4.0000 - tn: 127.0000 - fn: 43.0000 - accuracy: 0.7539 - precision: 0.8095 - recall: 0.2833 - auc: 0.7169 - val_loss: 0.5536 - val_tp: 3.0000 - val_fp: 0.0000e+00 - val_tn: 32.0000 - val_fn: 13.0000 - val_accuracy: 0.7292 - val_precision: 1.0000 - val_recall: 0.1875 - val_auc: 0.8242
# Epoch 71/100
#  32/191 [====>.........................] - ETA: 0s - loss: 0.5160 - tp: 1.0000 - fp: 0.0000e+00 - tn: 24.0000 - fn: 7.0000 - accuracy: 0.7812 - precision: 1.0000 - recall: 0.1250 - auc: 0.7240.
# 191/191 [==============================] - 0s 287us/sample - loss: 0.5625 - tp: 11.0000 - fp: 7.0000 - tn: 124.0000 - fn: 49.0000 - accuracy: 0.7068 - precision: 0.6111 - recall: 0.1833 - auc: 0.7047 - val_loss: 0.5520 - val_tp: 3.0000 - val_fp: 0.0000e+00 - val_tn: 32.0000 - val_fn: 13.0000 - val_accuracy: 0.7292 - val_precision: 1.0000 - val_recall: 0.1875 - val_auc: 0.8252
# Epoch 72/100
# 191/191 [==============================] - 0s 292us/sample - loss: 0.5808 - tp: 13.0000 - fp: 12.0000 - tn: 119.0000 - fn: 47.0000 - accuracy: 0.6911 - precision: 0.5200 - recall: 0.2167 - auc: 0.6779 - val_loss: 0.5509 - val_tp: 3.0000 - val_fp: 0.0000e+00 - val_tn: 32.0000 - val_fn: 13.0000 - val_accuracy: 0.7292 - val_precision: 1.0000 - val_recall: 0.1875 - val_auc: 0.8281
# Epoch 73/100
# 191/191 [==============================] - 0s 318us/sample - loss: 0.5592 - tp: 17.0000 - fp: 12.0000 - tn: 119.0000 - fn: 43.0000 - accuracy: 0.7120 - precision: 0.5862 - recall: 0.2833 - auc: 0.7212 - val_loss: 0.5496 - val_tp: 3.0000 - val_fp: 0.0000e+00 - val_tn: 32.0000 - val_fn: 13.0000 - val_accuracy: 0.7292 - val_precision: 1.0000 - val_recall: 0.1875 - val_auc: 0.8271
# Epoch 74/100
# 191/191 [==============================] - 0s 302us/sample - loss: 0.5747 - tp: 19.0000 - fp: 12.0000 - tn: 119.0000 - fn: 41.0000 - accuracy: 0.7225 - precision: 0.6129 - recall: 0.3167 - auc: 0.6812 - val_loss: 0.5484 - val_tp: 3.0000 - val_fp: 0.0000e+00 - val_tn: 32.0000 - val_fn: 13.0000 - val_accuracy: 0.7292 - val_precision: 1.0000 - val_recall: 0.1875 - val_auc: 0.8340
# Epoch 75/100
# 191/191 [==============================] - 0s 313us/sample - loss: 0.5447 - tp: 15.0000 - fp: 8.0000 - tn: 123.0000 - fn: 45.0000 - accuracy: 0.7225 - precision: 0.6522 - recall: 0.2500 - auc: 0.7424 - val_loss: 0.5475 - val_tp: 3.0000 - val_fp: 0.0000e+00 - val_tn: 32.0000 - val_fn: 13.0000 - val_accuracy: 0.7292 - val_precision: 1.0000 - val_recall: 0.1875 - val_auc: 0.8291
# Epoch 76/100
# 191/191 [==============================] - 0s 272us/sample - loss: 0.5677 - tp: 15.0000 - fp: 8.0000 - tn: 123.0000 - fn: 45.0000 - accuracy: 0.7225 - precision: 0.6522 - recall: 0.2500 - auc: 0.6946 - val_loss: 0.5459 - val_tp: 3.0000 - val_fp: 0.0000e+00 - val_tn: 32.0000 - val_fn: 13.0000 - val_accuracy: 0.7292 - val_precision: 1.0000 - val_recall: 0.1875 - val_auc: 0.8369
# Epoch 77/100
# 191/191 [==============================] - 0s 277us/sample - loss: 0.5376 - tp: 19.0000 - fp: 9.0000 - tn: 122.0000 - fn: 41.0000 - accuracy: 0.7382 - precision: 0.6786 - recall: 0.3167 - auc: 0.7626 - val_loss: 0.5440 - val_tp: 2.0000 - val_fp: 0.0000e+00 - val_tn: 32.0000 - val_fn: 14.0000 - val_accuracy: 0.7083 - val_precision: 1.0000 - val_recall: 0.1250 - val_auc: 0.8340
# Epoch 78/100
# 191/191 [==============================] - 0s 272us/sample - loss: 0.5721 - tp: 17.0000 - fp: 7.0000 - tn: 124.0000 - fn: 43.0000 - accuracy: 0.7382 - precision: 0.7083 - recall: 0.2833 - auc: 0.6785 - val_loss: 0.5428 - val_tp: 2.0000 - val_fp: 0.0000e+00 - val_tn: 32.0000 - val_fn: 14.0000 - val_accuracy: 0.7083 - val_precision: 1.0000 - val_recall: 0.1250 - val_auc: 0.8359
# Epoch 79/100
# 191/191 [==============================] - 0s 292us/sample - loss: 0.5375 - tp: 18.0000 - fp: 7.0000 - tn: 124.0000 - fn: 42.0000 - accuracy: 0.7435 - precision: 0.7200 - recall: 0.3000 - auc: 0.7529 - val_loss: 0.5414 - val_tp: 2.0000 - val_fp: 0.0000e+00 - val_tn: 32.0000 - val_fn: 14.0000 - val_accuracy: 0.7083 - val_precision: 1.0000 - val_recall: 0.1250 - val_auc: 0.8320
# Epoch 80/100
# 191/191 [==============================] - 0s 303us/sample - loss: 0.5303 - tp: 17.0000 - fp: 5.0000 - tn: 126.0000 - fn: 43.0000 - accuracy: 0.7487 - precision: 0.7727 - recall: 0.2833 - auc: 0.7534 - val_loss: 0.5403 - val_tp: 3.0000 - val_fp: 0.0000e+00 - val_tn: 32.0000 - val_fn: 13.0000 - val_accuracy: 0.7292 - val_precision: 1.0000 - val_recall: 0.1875 - val_auc: 0.8330
# Epoch 81/100
#  32/191 [====>.........................] - ETA: 0s - loss: 0.5874 - tp: 1.0000 - fp: 3.0000 - tn: 20.0000 - fn: 8.0000 - accuracy: 0.6562 - precision: 0.2500 - recall: 0.1111 - auc: 0.6135.
# 191/191 [==============================] - 0s 287us/sample - loss: 0.5905 - tp: 14.0000 - fp: 10.0000 - tn: 121.0000 - fn: 46.0000 - accuracy: 0.7068 - precision: 0.5833 - recall: 0.2333 - auc: 0.6643 - val_loss: 0.5394 - val_tp: 3.0000 - val_fp: 0.0000e+00 - val_tn: 32.0000 - val_fn: 13.0000 - val_accuracy: 0.7292 - val_precision: 1.0000 - val_recall: 0.1875 - val_auc: 0.8350
# Epoch 82/100
# 191/191 [==============================] - 0s 272us/sample - loss: 0.5640 - tp: 19.0000 - fp: 5.0000 - tn: 126.0000 - fn: 41.0000 - accuracy: 0.7592 - precision: 0.7917 - recall: 0.3167 - auc: 0.6906 - val_loss: 0.5389 - val_tp: 3.0000 - val_fp: 0.0000e+00 - val_tn: 32.0000 - val_fn: 13.0000 - val_accuracy: 0.7292 - val_precision: 1.0000 - val_recall: 0.1875 - val_auc: 0.8301
# Epoch 83/100
# 191/191 [==============================] - 0s 272us/sample - loss: 0.5490 - tp: 13.0000 - fp: 6.0000 - tn: 125.0000 - fn: 47.0000 - accuracy: 0.7225 - precision: 0.6842 - recall: 0.2167 - auc: 0.7357 - val_loss: 0.5382 - val_tp: 3.0000 - val_fp: 0.0000e+00 - val_tn: 32.0000 - val_fn: 13.0000 - val_accuracy: 0.7292 - val_precision: 1.0000 - val_recall: 0.1875 - val_auc: 0.8291
# Epoch 84/100
# 191/191 [==============================] - 0s 292us/sample - loss: 0.5584 - tp: 19.0000 - fp: 9.0000 - tn: 122.0000 - fn: 41.0000 - accuracy: 0.7382 - precision: 0.6786 - recall: 0.3167 - auc: 0.7190 - val_loss: 0.5369 - val_tp: 3.0000 - val_fp: 0.0000e+00 - val_tn: 32.0000 - val_fn: 13.0000 - val_accuracy: 0.7292 - val_precision: 1.0000 - val_recall: 0.1875 - val_auc: 0.8301
# Epoch 85/100
# 191/191 [==============================] - 0s 298us/sample - loss: 0.5569 - tp: 16.0000 - fp: 5.0000 - tn: 126.0000 - fn: 44.0000 - accuracy: 0.7435 - precision: 0.7619 - recall: 0.2667 - auc: 0.7001 - val_loss: 0.5361 - val_tp: 3.0000 - val_fp: 0.0000e+00 - val_tn: 32.0000 - val_fn: 13.0000 - val_accuracy: 0.7292 - val_precision: 1.0000 - val_recall: 0.1875 - val_auc: 0.8301
# Epoch 86/100
#  32/191 [====>.........................] - ETA: 0s - loss: 0.5072 - tp: 2.0000 - fp: 2.0000 - tn: 22.0000 - fn: 6.0000 - accuracy: 0.7500 - precision: 0.5000 - recall: 0.2500 - auc: 0.7161Restoring model weights from the end of the best epoch.
# 191/191 [==============================] - 0s 287us/sample - loss: 0.5179 - tp: 21.0000 - fp: 13.0000 - tn: 118.0000 - fn: 39.0000 - accuracy: 0.7277 - precision: 0.6176 - recall: 0.3500 - auc: 0.7774 - val_loss: 0.5352 - val_tp: 4.0000 - val_fp: 0.0000e+00 - val_tn: 32.0000 - val_fn: 12.0000 - val_accuracy: 0.7500 - val_precision: 1.0000 - val_recall: 0.2500 - val_auc: 0.8301
# Epoch 00086: early stopping

# %%
util.plot_metrics(non_resampled_history)

# %% [markdown]
# # Evaluate the Model

# %%
#test_y = test.pop('DEATH_EVENT')
#test_x = test
test_predictions_no_r = model.predict(test_x, batch_size=mobj.BATCH_SIZE)

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix

#print(test_y.shape)
#print(test_predictions_no_r.shape)
#print(test_predictions_no_r)

bscore_no_res = balanced_accuracy_score(test_y, keras.utils.to_categorical(test_predictions_no_r))

cm = confusion_matrix(test_y, keras.utils.to_categorical(test_predictions_no_r))
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Balanced Accuracy Score: {0}'.format(bscore_no_res)
plt.title(all_sample_title, size = 15);

# %%
no_res_results = model.evaluate(test_x, test_y,
                                  batch_size=mobj.BATCH_SIZE, verbose=0)
for name, value in zip(model.metrics_names, no_res_results):
  print(name, ': ', value)
print()
# Out:
# loss :  0.5058390339215596
# tp :  7.0
# fp :  1.0
# tn :  39.0
# fn :  13.0
# accuracy :  0.76666665
# precision :  0.875
# recall :  0.35
# auc :  0.89250004

# %% [markdown]
# # UnderSampling (NearMiss1)

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# 25%            30.000000             0.000000  212500.000000
# 50%            38.000000             0.000000  262000.000000
# 75%            45.000000             1.000000  303500.000000
# max            80.000000             1.000000  850000.000000
#
#        serum_creatinine  serum_sodium         sex    smoking        time  \
# count         299.00000    299.000000  299.000000  299.00000  299.000000
# mean            1.39388    136.625418    0.648829    0.32107  130.260870
# std             1.03451      4.412477    0.478136    0.46767   77.614208
# min             0.50000    113.000000    0.000000    0.00000    4.000000
# 25%             0.90000    134.000000    0.000000    0.00000   73.000000
# 50%             1.10000    137.000000    1.000000    0.00000  115.000000
# 75%             1.40000    140.000000    1.000000    1.00000  203.000000
# max             9.40000    148.000000    1.000000    1.00000  285.000000
#
#        DEATH_EVENT
# count    299.00000
# mean       0.32107
# std        0.46767
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        1.00000
# max        1.00000

# %% [markdown]
# # Apply Resampling to Dataset

# %%
from imblearn.under_sampling import NearMiss

raw_df = df.copy(deep=True)

y = raw_df.pop('DEATH_EVENT')
X = raw_df

nm1 = NearMiss(version=1)

X_resampled, y_resampled = nm1.fit_sample(X, y)

nm1_df = pd.DataFrame(X_resampled, columns=X.columns)
nm1_df['DEATH_EVENT'] = y_resampled
nm1_df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 45
# 1  67.0        0                       582         0                 50
# 2  75.0        0                       582         0                 40
# 3  42.0        0                       582         0                 60
# 4  45.0        0                       582         0                 80
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  263358.03              1.18           137    1
# 1                    0  263358.03              1.18           137    1
# 2                    0  263358.03              1.18           137    1
# 3                    0  263358.03              1.18           137    0
# 4                    0  263358.03              1.18           137    0
#
#    smoking  time  DEATH_EVENT
# 0        0    87            0
# 1        1    76            0
# 2        0   107            0
# 3        0    82            0
# 4        0    63            0

# %%
nm1_df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  192.000000  192.000000                192.000000  192.000000
# mean    61.902781    0.432292                553.838542    0.432292
# std     12.373282    0.496690                991.173962    0.496690
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     52.750000    0.000000                122.750000    0.000000
# 50%     60.000000    0.000000                249.500000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         192.000000           192.000000     192.000000
# mean           36.765625             0.385417  250004.951823
# std            12.416518             0.487966   76715.286484
# min            14.000000             0.000000   47000.000000
# 25%            25.000000             0.000000  210750.000000
# 50%            35.000000             0.000000  254000.000000
# 75%            40.000000             1.000000  271000.000000
# max            80.000000             1.000000  621000.000000
#
#        serum_creatinine  serum_sodium         sex     smoking        time  \
# count        192.000000    192.000000  192.000000  192.000000  192.000000
# mean           1.498490    136.062500    0.630208    0.307292  111.171875
# std            1.150881      4.806872    0.484010    0.462578   76.025049
# min            0.600000    113.000000    0.000000    0.000000    4.000000
# 25%            1.000000    134.000000    0.000000    0.000000   43.000000
# 50%            1.180000    136.000000    1.000000    0.000000   94.500000
# 75%            1.600000    139.000000    1.000000    1.000000  181.250000
# max            9.400000    146.000000    1.000000    1.000000  271.000000
#
#        DEATH_EVENT
# count   192.000000
# mean      0.500000
# std       0.501307
# min       0.000000
# 25%       0.000000
# 50%       0.500000
# 75%       1.000000
# max       1.000000

# %% [markdown]
# # Train/Test Split

# %%
train, test = train_test_split(nm1_df, test_size=0.2)

# %% [markdown]
# # Create New Model

# %%
# Create Model 

import models

# set initial bias
neg, pos = np.bincount(nm1_df['DEATH_EVENT'])# set count negative and positive samples
initial_bias = np.log([pos/neg])

mobj = models.modelObj()
model = mobj.create_model(len(train.keys())-1, bias = initial_bias)

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 16)                208
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 225
# Trainable params: 225
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Normalize Data

# %%
# Normalize Data

train_y = train.pop('DEATH_EVENT')
train_x = util.norm(train)
train_x.head()

test_y = test.pop('DEATH_EVENT')
test_x = util.norm(test)
train_x.head()
# Out:
#          0    1         2    3         4    5         6         7         8   \
# 0  1.000000  1.0  0.011355  0.0  0.384615  1.0  0.259582  0.045455  0.757576
# 1  0.636364  0.0  0.083184  1.0  0.692308  0.0  0.379791  0.090909  0.363636
# 2  0.545455  1.0  0.005869  1.0  0.538462  1.0  0.529617  0.045455  0.636364
# 3  0.527273  0.0  0.071319  0.0  0.076923  0.0  0.381533  0.068182  0.636364
# 4  0.363636  0.0  0.238964  1.0  0.153846  0.0  0.554007  0.170455  0.939394
#
#     9    10        11
# 0  0.0  0.0  0.074906
# 1  0.0  0.0  0.752809
# 2  0.0  0.0  0.149813
# 3  1.0  1.0  0.258427
# 4  0.0  0.0  0.629213

# %%
nm1_resampled_history = model.fit(
    train_x,
    train_y,
    batch_size=mobj.BATCH_SIZE,
    epochs=mobj.EPOCHS,
    callbacks = [early_stopping, models.printDot()],
    validation_split=0.2)
# Out:
# Train on 122 samples, validate on 31 samples
# Epoch 1/100
#  32/122 [======>.......................] - ETA: 4s - loss: 0.7395 - tp: 1.0000 - fp: 3.0000 - tn: 15.0000 - fn: 13.0000 - accuracy: 0.5000 - precision: 0.2500 - recall: 0.0714 - auc: 0.3413.
# 122/122 [==============================] - 2s 19ms/sample - loss: 0.7011 - tp: 15.0000 - fp: 8.0000 - tn: 52.0000 - fn: 47.0000 - accuracy: 0.5492 - precision: 0.6522 - recall: 0.2419 - auc: 0.5449 - val_loss: 0.6905 - val_tp: 3.0000 - val_fp: 0.0000e+00 - val_tn: 14.0000 - val_fn: 14.0000 - val_accuracy: 0.5484 - val_precision: 1.0000 - val_recall: 0.1765 - val_auc: 0.6954
# Epoch 2/100
# 122/122 [==============================] - 0s 343us/sample - loss: 0.7049 - tp: 15.0000 - fp: 9.0000 - tn: 51.0000 - fn: 47.0000 - accuracy: 0.5410 - precision: 0.6250 - recall: 0.2419 - auc: 0.5011 - val_loss: 0.6887 - val_tp: 3.0000 - val_fp: 0.0000e+00 - val_tn: 14.0000 - val_fn: 14.0000 - val_accuracy: 0.5484 - val_precision: 1.0000 - val_recall: 0.1765 - val_auc: 0.7080
# Epoch 3/100
# 122/122 [==============================] - 0s 352us/sample - loss: 0.7076 - tp: 11.0000 - fp: 12.0000 - tn: 48.0000 - fn: 51.0000 - accuracy: 0.4836 - precision: 0.4783 - recall: 0.1774 - auc: 0.5120 - val_loss: 0.6872 - val_tp: 4.0000 - val_fp: 0.0000e+00 - val_tn: 14.0000 - val_fn: 13.0000 - val_accuracy: 0.5806 - val_precision: 1.0000 - val_recall: 0.2353 - val_auc: 0.6933
# Epoch 4/100
# 122/122 [==============================] - 0s 376us/sample - loss: 0.7057 - tp: 17.0000 - fp: 14.0000 - tn: 46.0000 - fn: 45.0000 - accuracy: 0.5164 - precision: 0.5484 - recall: 0.2742 - auc: 0.5124 - val_loss: 0.6859 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 14.0000 - val_fn: 12.0000 - val_accuracy: 0.6129 - val_precision: 1.0000 - val_recall: 0.2941 - val_auc: 0.6996
# Epoch 5/100
# 122/122 [==============================] - 0s 368us/sample - loss: 0.6945 - tp: 24.0000 - fp: 13.0000 - tn: 47.0000 - fn: 38.0000 - accuracy: 0.5820 - precision: 0.6486 - recall: 0.3871 - auc: 0.5802 - val_loss: 0.6849 - val_tp: 5.0000 - val_fp: 1.0000 - val_tn: 13.0000 - val_fn: 12.0000 - val_accuracy: 0.5806 - val_precision: 0.8333 - val_recall: 0.2941 - val_auc: 0.7017
# Epoch 6/100
# 122/122 [==============================] - 0s 401us/sample - loss: 0.6879 - tp: 22.0000 - fp: 14.0000 - tn: 46.0000 - fn: 40.0000 - accuracy: 0.5574 - precision: 0.6111 - recall: 0.3548 - auc: 0.6013 - val_loss: 0.6841 - val_tp: 5.0000 - val_fp: 1.0000 - val_tn: 13.0000 - val_fn: 12.0000 - val_accuracy: 0.5806 - val_precision: 0.8333 - val_recall: 0.2941 - val_auc: 0.6975
# Epoch 7/100
# 122/122 [==============================] - 0s 401us/sample - loss: 0.7059 - tp: 21.0000 - fp: 18.0000 - tn: 42.0000 - fn: 41.0000 - accuracy: 0.5164 - precision: 0.5385 - recall: 0.3387 - auc: 0.5118 - val_loss: 0.6835 - val_tp: 6.0000 - val_fp: 2.0000 - val_tn: 12.0000 - val_fn: 11.0000 - val_accuracy: 0.5806 - val_precision: 0.7500 - val_recall: 0.3529 - val_auc: 0.6912
# Epoch 8/100
# 122/122 [==============================] - 0s 376us/sample - loss: 0.7024 - tp: 18.0000 - fp: 19.0000 - tn: 41.0000 - fn: 44.0000 - accuracy: 0.4836 - precision: 0.4865 - recall: 0.2903 - auc: 0.4970 - val_loss: 0.6829 - val_tp: 6.0000 - val_fp: 3.0000 - val_tn: 11.0000 - val_fn: 11.0000 - val_accuracy: 0.5484 - val_precision: 0.6667 - val_recall: 0.3529 - val_auc: 0.6975
# Epoch 9/100
# 122/122 [==============================] - 0s 392us/sample - loss: 0.7158 - tp: 18.0000 - fp: 23.0000 - tn: 37.0000 - fn: 44.0000 - accuracy: 0.4508 - precision: 0.4390 - recall: 0.2903 - auc: 0.4300 - val_loss: 0.6821 - val_tp: 6.0000 - val_fp: 3.0000 - val_tn: 11.0000 - val_fn: 11.0000 - val_accuracy: 0.5484 - val_precision: 0.6667 - val_recall: 0.3529 - val_auc: 0.6912
# Epoch 10/100
# 122/122 [==============================] - 0s 384us/sample - loss: 0.7010 - tp: 22.0000 - fp: 20.0000 - tn: 40.0000 - fn: 40.0000 - accuracy: 0.5082 - precision: 0.5238 - recall: 0.3548 - auc: 0.4949 - val_loss: 0.6814 - val_tp: 8.0000 - val_fp: 3.0000 - val_tn: 11.0000 - val_fn: 9.0000 - val_accuracy: 0.6129 - val_precision: 0.7273 - val_recall: 0.4706 - val_auc: 0.6765
# Epoch 11/100
#  32/122 [======>.......................] - ETA: 0s - loss: 0.6940 - tp: 1.0000 - fp: 10.0000 - tn: 11.0000 - fn: 10.0000 - accuracy: 0.3750 - precision: 0.0909 - recall: 0.0909 - auc: 0.3983.
# 122/122 [==============================] - 0s 343us/sample - loss: 0.6986 - tp: 21.0000 - fp: 20.0000 - tn: 40.0000 - fn: 41.0000 - accuracy: 0.5000 - precision: 0.5122 - recall: 0.3387 - auc: 0.5028 - val_loss: 0.6805 - val_tp: 9.0000 - val_fp: 3.0000 - val_tn: 11.0000 - val_fn: 8.0000 - val_accuracy: 0.6452 - val_precision: 0.7500 - val_recall: 0.5294 - val_auc: 0.6765
# Epoch 12/100
#  32/122 [======>.......................] - ETA: 0s - loss: 0.7235 - tp: 6.0000 - fp: 8.0000 - tn: 9.0000 - fn: 9.0000 - accuracy: 0.4688 - precision: 0.4286 - recall: 0.4000 - auc: 0.4216Restoring model weights from the end of the best epoch.
# 122/122 [==============================] - 0s 376us/sample - loss: 0.6956 - tp: 22.0000 - fp: 21.0000 - tn: 39.0000 - fn: 40.0000 - accuracy: 0.5000 - precision: 0.5116 - recall: 0.3548 - auc: 0.5339 - val_loss: 0.6796 - val_tp: 10.0000 - val_fp: 3.0000 - val_tn: 11.0000 - val_fn: 7.0000 - val_accuracy: 0.6774 - val_precision: 0.7692 - val_recall: 0.5882 - val_auc: 0.6786
# Epoch 00012: early stopping

# %%
util.plot_metrics(nm1_resampled_history)

# %% [markdown]
# # Evaluate Model

# %%
#test_y = test.pop('DEATH_EVENT')
#test_x = test
test_predictions_nm1 = model.predict(test_x, batch_size=mobj.BATCH_SIZE)


bscore_no_res = balanced_accuracy_score(test_y, keras.utils.to_categorical(test_predictions_nm1))

cm = confusion_matrix(test_y, keras.utils.to_categorical(test_predictions_nm1))
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Balanced Accuracy Score: {0}'.format(bscore_no_res)
plt.title(all_sample_title, size = 15);

nm1_results = model.evaluate(test_x, test_y,
                                  batch_size=mobj.BATCH_SIZE, verbose=0)
for name, value in zip(model.metrics_names, no_res_results):
  print(name, ': ', value)
print()
# Out:
# loss :  0.5058390339215596
# tp :  7.0
# fp :  1.0
# tn :  39.0
# fn :  13.0
# accuracy :  0.76666665
# precision :  0.875
# recall :  0.35
# auc :  0.89250004

# %% [markdown]
# # OneSidedSelection

# %%
raw_df = df.copy(deep=True)
raw_df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %% [markdown]
# Using batch generator from imbalanced learn

# %%
train, test = train_test_split(nm1_df, test_size=0.2)

# %%
# set initial bias
neg, pos = np.bincount(raw_df['DEATH_EVENT'])# set count negative and positive samples
initial_bias = np.log([pos/neg])

# %% [markdown]
# # Normalize Data

# %%
# Create Model
#y = train.pop('DEATH_EVENT')
#y_train = keras.utils.to_categorical(y, 3)
y_train =train.pop('DEATH_EVENT')
X_train = train
y_test =test.pop('DEATH_EVENT')
X_test = test
mobj = models.modelObj()
model = mobj.create_model(len(X.keys())-1, bias = initial_bias)

# %%
X_train = util.norm(X_train)
X_test = util.norm(X_test)
train_x.head()
# Out:
#          0    1         2    3         4    5         6         7         8   \
# 0  1.000000  1.0  0.011355  0.0  0.384615  1.0  0.259582  0.045455  0.757576
# 1  0.636364  0.0  0.083184  1.0  0.692308  0.0  0.379791  0.090909  0.363636
# 2  0.545455  1.0  0.005869  1.0  0.538462  1.0  0.529617  0.045455  0.636364
# 3  0.527273  0.0  0.071319  0.0  0.076923  0.0  0.381533  0.068182  0.636364
# 4  0.363636  0.0  0.238964  1.0  0.153846  0.0  0.554007  0.170455  0.939394
#
#     9    10        11
# 0  0.0  0.0  0.074906
# 1  0.0  0.0  0.752809
# 2  0.0  0.0  0.149813
# 3  1.0  1.0  0.258427
# 4  0.0  0.0  0.629213

# %%
from imblearn.keras import balanced_batch_generator
from imblearn.under_sampling import OneSidedSelection

# fit the model using generator
training_generator, steps_per_epoch = balanced_batch_generator(
    X_train, y_train, sampler=OneSidedSelection(random_state=0), batch_size=mobj.BATCH_SIZE, random_state=42)

callback_history_oss = model.fit_generator(generator=training_generator,
                                        steps_per_epoch=steps_per_epoch,
                                        epochs=mobj.EPOCHS, verbose=0)
# Out:
# WARNING:tensorflow:From <ipython-input-30-1e5e047ca10f>:10: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-30-1e5e047ca10f> in <module>
#       8 callback_history_oss = model.fit_generator(generator=training_generator,
#       9                                         steps_per_epoch=steps_per_epoch,
# ---> 10                                         epochs=mobj.EPOCHS, verbose=0)
#
# ~\Anaconda3\envs\tfGPU\lib\site-packages\tensorflow_core\python\util\deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# ~\Anaconda3\envs\tfGPU\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1304         use_multiprocessing=use_multiprocessing,
#    1305         shuffle=shuffle,
# -> 1306         initial_epoch=initial_epoch)
#    1307
#    1308   @deprecation.deprecated(
#
# ~\Anaconda3\envs\tfGPU\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# ~\Anaconda3\envs\tfGPU\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# ~\Anaconda3\envs\tfGPU\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# ~\Anaconda3\envs\tfGPU\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# ~\Anaconda3\envs\tfGPU\lib\site-packages\tensorflow_core\python\eager\def_function.py in __call__(self, *args, **kwds)
#     566         xla_context.Exit()
#     567     else:
# --> 568       result = self._call(*args, **kwds)
#     569
#     570     if tracing_count == self._get_tracing_count():
#
# ~\Anaconda3\envs\tfGPU\lib\site-packages\tensorflow_core\python\eager\def_function.py in _call(self, *args, **kwds)
#     630         # Lifting succeeded, so variables are initialized and we can run the
#     631         # stateless function.
# --> 632         return self._stateless_fn(*args, **kwds)
#     633     else:
#     634       canon_args, canon_kwds = \
#
# ~\Anaconda3\envs\tfGPU\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    2361     with self._lock:
#    2362       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2363     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2364
#    2365   @property
#
# ~\Anaconda3\envs\tfGPU\lib\site-packages\tensorflow_core\python\eager\function.py in _filtered_call(self, args, kwargs)
#    1609          if isinstance(t, (ops.Tensor,
#    1610                            resource_variable_ops.BaseResourceVariable))),
# -> 1611         self.captured_inputs)
#    1612
#    1613   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~\Anaconda3\envs\tfGPU\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# ~\Anaconda3\envs\tfGPU\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# ~\Anaconda3\envs\tfGPU\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      65     else:
#      66       message = e.message
# ---> 67     six.raise_from(core._status_to_exception(e.code, message), None)
#      68   except TypeError as e:
#      69     keras_symbolic_tensors = [
#
# ~\AppData\Roaming\Python\Python37\site-packages\six.py in raise_from(value, from_value)
#
# InvalidArgumentError: 2 root error(s) found.
#   (0) Invalid argument:  Matrix size-incompatible: In[0]: [32,12], In[1]: [11,16]
# 	 [[node sequential_2/dense_4/MatMul (defined at <ipython-input-30-1e5e047ca10f>:10) ]]
# 	 [[metrics/fp/assert_less_equal/Assert/AssertGuard/pivot_f/_41/_75]]
#   (1) Invalid argument:  Matrix size-incompatible: In[0]: [32,12], In[1]: [11,16]
# 	 [[node sequential_2/dense_4/MatMul (defined at <ipython-input-30-1e5e047ca10f>:10) ]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_distributed_function_22986]
#
# Function call stack:
# distributed_function -> distributed_function
